# %% [markdown]
# <a href="https://colab.research.google.com/github/Jkanishkha0305/self_driving_car/blob/main/openai/taxi_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy
import random
from os import system, name
from time import sleep

# %%
# Define function to clear console window.
def clear(): 
  
    # Clear on Windows.
    if name == 'nt': 
        _ = system('cls')
  
    # Clear on Mac and Linux. (os.name is 'posix') 
    else: 
        _ = system('clear')

clear()

# %%
#import environment and setup 
env = gym.make("Taxi-v3") # Setup the Gym Environment
env
# Out:
# <TimeLimit<TaxiEnv<Taxi-v3>>>

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n
print("states : " + str(n_states))
print("actions : " + str(n_actions))
# 0-up , 1-down , 2-left , 3-right , 4-pickup , 5-dropoff
# Out:
# states : 500
# actions : 6

# %%
env.env.s = 200 
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
env.reset()
env.step(1)
# Out:
# (164, -1, False, {'prob': 1.0})

# %% [markdown]
# Solved Without Q-Learning

# %%
state = env.reset()
counter = 0 
g = 0 
reward = None

# %%
while reward !=20:
  state, reward, done, info = env.step(env.action_space.sample())
  counter += 1
  g += reward 
print("Solved in {} Steps with a total reward of {}".format(counter,g))
# Out:
# Solved in 1536 Steps with a total reward of -5925

# %% [markdown]
# Applying Q-learning to Solve

# %%
#Applying Q-Learning

# Make a new matrix filled with zeros.
# The matrix will be 500x6 as there are 500 states and 6 actions.
q_table = numpy.zeros([env.observation_space.n, env.action_space.n])

training_episodes = 2000 # Amount of times to run environment while training.
display_episodes = 10 # Amount of times to run environment after training.

# Hyperparameters
alpha = 0.1 # Learning Rate
gamma = 0.6 # Discount Rate
epsilon = 0.1 # Chance of selecting a random action instead of maximising reward.

# For plotting metrics
all_epochs = []
all_penalties = []

# %%
#Training the Agent

for i in range(training_episodes):
    state = env.reset()
    done = False
    penalties, reward, G = 0, 0, 0
    
    while not done:
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample() # Pick a new action for this state.
        else:
            action = numpy.argmax(q_table[state]) # Pick the action which has previously given the highest reward.

        next_state, reward, done, info = env.step(action) 
        
        old_value = q_table[state, action] # Retrieve old value from the q-table.
        next_max = numpy.max(q_table[next_state])

        # Update q-value for current state.
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state, action] = new_value

        G += reward

        if reward == -10: # Checks if agent attempted to do an illegal action.
            penalties += 1

        state = next_state
        
    if i % 100 == 0: # Output number of completed episodes every 100 episodes.
        print(f"Episode: {i} Total Reward: {G}")

print("Training finished.\n")
# Out:
# Episode: 0 Total Reward: -551
# Episode: 100 Total Reward: -209
# Episode: 200 Total Reward: -300
# Episode: 300 Total Reward: -86
# Episode: 400 Total Reward: -238
# Episode: 500 Total Reward: -245
# Episode: 600 Total Reward: -112
# Episode: 700 Total Reward: -9
# Episode: 800 Total Reward: 3
# Episode: 900 Total Reward: -63
# Episode: 1000 Total Reward: -107
# Episode: 1100 Total Reward: -1
# Episode: 1200 Total Reward: -73
# Episode: 1300 Total Reward: 6
# Episode: 1400 Total Reward: -34
# Episode: 1500 Total Reward: -5
# Episode: 1600 Total Reward: -68
# Episode: 1700 Total Reward: -14
# Episode: 1800 Total Reward: -20
# Episode: 1900 Total Reward: 15
# Training finished.

# %%
#Display and evaluate agent's performance after Q-learning.

total_epochs, total_penalties = 0, 0

for _ in range(display_episodes):
    state = env.reset()
    epochs, penalties, reward = 0, 0, 0
    
    done = False
    
    while not done:
        action = numpy.argmax(q_table[state])
        state, reward, done, info = env.step(action)

        if reward == -10:
            penalties += 1

        epochs += 1
        clear()
        env.render()
        print(f"Timestep: {epochs}")
        print(f"State: {state}")
        print(f"Action: {action}")
        print(f"Reward: {reward}")
        sleep(0.15) # Sleep so the user can see the 

    total_penalties += penalties
    total_epochs += epochs

print(f"Results after {display_episodes} episodes:")
print(f"Average timesteps per episode: {total_epochs / display_episodes}")
print(f"Average penalties per episode: {total_penalties / display_episodes}")
# Out:
# Streaming output truncated to the last 5000 lines.
#   (South)
# Timestep: 184
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 185
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 186
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 187
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 188
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 189
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 190
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 191
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 192
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 193
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 194
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 195
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 196
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 197
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 198
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 199
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 200
# State: 483
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 1
# State: 307
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 2
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 3
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 4
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 5
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 6
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 7
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 8
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 9
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 10
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 11
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 12
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 13
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 14
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 15
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 16
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 17
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 18
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 19
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 20
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 21
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 22
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 23
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 24
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 25
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 26
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 27
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 28
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 29
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 30
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 31
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 32
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 33
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 34
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 35
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 36
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 37
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 38
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 39
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 40
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 41
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 42
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 43
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 44
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 45
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 46
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 47
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 48
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 49
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 50
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 51
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 52
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 53
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 54
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 55
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 56
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 57
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 58
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 59
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 60
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 61
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 62
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 63
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 64
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 65
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 66
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 67
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 68
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 69
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 70
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 71
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 72
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 73
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 74
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 75
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 76
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 77
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 78
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 79
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 80
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 81
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 82
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 83
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 84
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 85
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 86
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 87
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 88
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 89
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 90
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 91
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 92
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 93
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 94
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 95
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 96
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 97
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 98
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 99
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 100
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 101
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 102
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 103
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 104
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 105
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 106
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 107
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 108
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 109
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 110
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 111
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 112
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 113
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 114
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 115
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 116
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 117
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 118
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 119
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 120
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 121
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 122
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 123
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 124
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 125
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 126
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 127
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 128
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 129
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 130
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 131
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 132
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 133
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 134
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: 135
# State: 407
# Action: 0
# Reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
# Timestep: